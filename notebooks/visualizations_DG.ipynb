# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#set font size of labels on matplotlib plots
plt.rc('font', size=12)

#set style of plots
sns.set_style('white')

#define a custom palette
customPalette = ['#7F0009', '#231F20', '#A29060', '#FFB139']
sns.set_palette(customPalette)
sns.palplot(customPalette)

# %%
data = pd.read_csv("../data/processed/summary_table.csv") 
# Preview the first 5 lines of the loaded data 
data
# Out:
#     Unnamed: 0  club_id                    club  Goals_For  Goals_Against  \
# 0            0     23.0              Toronto FC       57.0           52.0
# 1            1      9.0               LA Galaxy       58.0           59.0
# 2            2      2.0            Chicago Fire       55.0           47.0
# 3            3     10.0                    LAFC       85.0           37.0
# 4            4     21.0     Seattle Sounders FC       52.0           49.0
# 5            5     12.0         Montreal Impact       47.0           60.0
# 6            6      1.0          Atlanta United       58.0           43.0
# 7            7     16.0         Orlando City SC       44.0           52.0
# 8            8     18.0        Portland Timbers       52.0           49.0
# 9            9     22.0    Sporting Kansas City       49.0           67.0
# 10          10     19.0          Real Salt Lake       46.0           41.0
# 11          11     11.0        Minnesota United       52.0           43.0
# ...

# %%
atl = pd.read_csv("../data/interim/league.csv") 
# Preview the first 5 lines of the loaded data 
atl["club"] == "Atlanta United"
atl = atl.iloc[1]

# %%
wins = atl['wins']
draws = atl['draws']
losses = atl['losses']
column1 = [wins, draws, losses]
total = atl['matches_played']
column1
# Out:
# [18, 4, 12]

# %%
#create and format the percentage of female vs male
wp = (wins/total)
dp = (draws/total)
lp = (losses/total)
column2 = [wp, dp, lp]
index = ['Wins', 'Draws', 'Losses']
atl_df = pd.DataFrame({"ATL United Games": column,'Performance by (%)': column2}, index)
atl_df
# Out:
#         ATL United Games  Performance by (%)
# Wins                  18            0.529412
# Draws                  4            0.117647
# Losses                12            0.352941

# %%
percent = atl_df["Performance by (%)"].map("{:.2%}".format)
# Munging
atl_df = atl_df.round(4)
atl_df
# Out:
#         ATL United Games  Performance by (%)
# Wins                  18              0.5294
# Draws                  4              0.1176
# Losses                12              0.3529

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
plot = atl_df.plot.pie(y= "ATL United Games", figsize=(5, 5), startangle=180, shadow = True, autopct= "%.2f%%")

# %%
# import matplotlib.pyplot as plt
# img = plt.imread("../images/Company-Updates_Atlanta-Falcons_Logo_Double.jpg")
# fig, ax = plt.subplots()
# ax.imshow(img)
# x =  data['club']
# y = data['Roster Payroll']
# z = data['Max Salary']
# k = data['Min Salary']

# ax = plt.subplot(111)
# ax.bar(x, y, width=0.2, color='b', align='center')
# ax.bar(x, z, width=0.2, color='g', align='center')
# ax.bar(x, k, width=0.2, color='r', align='center')
# ax.xaxis_date()

# plt.s
arr0 = data['club'].to_numpy()
arr0
# Out:
# array(['Toronto FC', 'LA Galaxy', 'Chicago Fire', 'LAFC',
#        'Seattle Sounders FC', 'Montreal Impact', 'Atlanta United',
#        'Orlando City SC', 'Portland Timbers', 'Sporting Kansas City',
#        'Real Salt Lake', 'Minnesota United', 'San Jose Earthquakes',
#        'Columbus Crew', 'New England Revolution', 'New York City FC',
#        'DC United', 'Philadelphia Union', 'FC Cincinnati', 'FC Dallas',
#        'Houston Dynamo', 'New York Red Bulls', 'Colorado Rapids',
#        'Vancouver Whitecaps'], dtype=object)

# %%
arr = data['Roster Payroll'].to_numpy()
arr1 = data['Max Salary'].to_numpy()
arr2 = data['Mean Salary'].to_numpy()
arr3 = data['Min Salary'].to_numpy()

# %%
def bar_plot(ax, data, colors=None, total_width=0.8, single_width=1, legend=True):
    """Draws a bar plot with multiple bars per data point.

    Parameters
    ----------
    ax : matplotlib.pyplot.axis
        The axis we want to draw our plot on.

    data: dictionary
        A dictionary containing the data we want to plot. Keys are the names of the
        data, the items is a list of the values.

        Example:
        data = {
            "x":[1,2,3],
            "y":[1,2,3],
            "z":[1,2,3],
        }

    colors : array-like, optional
        A list of colors which are used for the bars. If None, the colors
        will be the standard matplotlib color cyle. (default: None)

    total_width : float, optional, default: 0.8
        The width of a bar group. 0.8 means that 80% of the x-axis is covered
        by bars and 20% will be spaces between the bars.

    single_width: float, optional, default: 1
        The relative width of a single bar within a group. 1 means the bars
        will touch eachother within a group, values less than 1 will make
        these bars thinner.

    legend: bool, optional, default: True
        If this is set to true, a legend will be added to the axis.
    """

    # Check if colors where provided, otherwhise use the default color cycle
    if colors is None:
        colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

    # Number of bars per group
    n_bars = len(data)

    # The width of a single bar
    bar_width = total_width / n_bars

    # List containing handles for the drawn bars, used for the legend
    bars = []
    # Iterate over all data
    for i, (name, values) in enumerate(data.items()):
        # The offset in x direction of that bar
        x_offset = (i - n_bars / 2) * bar_width + bar_width / 2

        # Draw a bar for every value of that type
        for x, y in enumerate(values):
            bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)])

        # Add a handle to the last drawn bar, which we'll need for the legend
        bars.append(bar[0])

    # Draw legend if we need
    if legend:
        ax.legend(bars, data.keys())

if __name__ == "__main__":
    # This will collapse each row to a list:
    data = {

        "Roster Payroll": arr,
        "Max Salary": arr1,
        "Mean Salary": arr2,
        "Min Salary": arr3
    }
#     plt.xlim([4, 100])
#     plt.ylim([45, 65])
#     ax.imshow(img)
#     img = plt.imread("../images/Company-Updates_Atlanta-Falcons_Logo_Double.jpg")
    fig, ax = plt.subplots(figsize=(10,8))
    bar_plot(ax, data, total_width=.8, single_width=1) 
#      Locators and Formatters are set to be static using set_*ticklabels or ax.*axis.set_ticklabels:
    label = [item.get_text() for item in ax.get_xticklabels()]
#     for loop to pull names from the array you have created:
    label = [label for label in arr0]
    x_ticks = np.arange(0, 24, 1)
    plt.xticks(x_ticks, labels= label, rotation= 85)
    plt.savefig('../reports/figures/Salary.png')
    plt.show()

# %%
plot = atl_df.plot.pie(y= "ATL United Games", figsize=(10, 8), startangle=180, shadow = True, autopct= "%.2f%%")
plt.savefig('../reports/figures/united.png')
plt.show()
