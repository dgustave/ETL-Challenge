# %%
import pandas as pd
import matplotlib as plt
import numpy as py

# %%
url = 'https://mlsplayers.org/resources/salary-guide'

# %%
tables = pd.read_html(url)
type(tables)
# Out:
# list

# %%
df = tables[0]
df
# Out:
#     First Name     Last Name                  Club Position(s)    Base Salary  \
# 0      Brenden      Aaronson    Philadelphia Union         M-F     $70,000.08
# 1         Saad  Abdul-Salaam   Seattle Sounders FC           D     $70,250.04
# 2        Lalas      Abubakar       Colorado Rapids           D    $135,000.00
# 3        David         Accam         Columbus Crew         M-F  $1,010,004.00
# 4       Kellyn        Acosta       Colorado Rapids         D-M    $549,999.96
# ..         ...           ...                   ...         ...            ...
# 709       Reto       Ziegler             FC Dallas           D    $820,000.08
# 710     Walker     Zimmerman                  LAFC           D    $600,000.00
# 711       Kyle        Zobeck             FC Dallas          GK     $70,875.00
# 712      Ethan         Zubak             LA Galaxy           F     $75,000.00
# 713     Graham          Zusi  Sporting Kansas City         D-M    $625,000.08
#
#     Guaranteed Compensation
# 0                $98,309.48
# 1                $70,250.04
# 2               $144,937.50
# 3             $1,137,920.00
# 4               $664,999.96
# ..                      ...
# 709             $870,000.08
# 710             $600,000.00
# 711              $70,875.00
# 712              $78,125.00
# 713             $688,333.41
#
# [714 rows x 6 columns]

# %%
# convert 'Base Salary' and 'Guaranteed Compensation' from object to float datatypes so we can aggregate
df['Base Salary'] = df['Base Salary'].replace( '[\$,)]','', regex=True ).replace( '','NaN',regex=True ).astype(float)
df['Guaranteed Compensation'] = df['Guaranteed Compensation'].replace( '[\$,)]','', regex=True ).replace( '','NaN',regex=True ).astype(float)
df
# Out:
#     First Name     Last Name                  Club Position(s)  Base Salary  \
# 0      Brenden      Aaronson    Philadelphia Union         M-F     70000.08
# 1         Saad  Abdul-Salaam   Seattle Sounders FC           D     70250.04
# 2        Lalas      Abubakar       Colorado Rapids           D    135000.00
# 3        David         Accam         Columbus Crew         M-F   1010004.00
# 4       Kellyn        Acosta       Colorado Rapids         D-M    549999.96
# ..         ...           ...                   ...         ...          ...
# 709       Reto       Ziegler             FC Dallas           D    820000.08
# 710     Walker     Zimmerman                  LAFC           D    600000.00
# 711       Kyle        Zobeck             FC Dallas          GK     70875.00
# 712      Ethan         Zubak             LA Galaxy           F     75000.00
# 713     Graham          Zusi  Sporting Kansas City         D-M    625000.08
#
#      Guaranteed Compensation
# 0                   98309.48
# 1                   70250.04
# 2                  144937.50
# 3                 1137920.00
# 4                  664999.96
# ..                       ...
# 709                870000.08
# 710                600000.00
# 711                 70875.00
# 712                 78125.00
# 713                688333.41
#
# [714 rows x 6 columns]

# %%
df['Club'].nunique()
# Out:
# 27

# %%
df['Club'].value_counts()
# Out:
# FC Cincinnati             33
# Toronto FC                32
# Atlanta United            32
# FC Dallas                 31
# Real Salt Lake            31
# San Jose Earthquakes      31
# LA Galaxy                 30
# Orlando City SC           30
# Vancouver Whitecaps       30
# Montreal Impact           30
# Sporting Kansas City      29
# Columbus Crew             29
# New York Red Bulls        29
# Philadelphia Union        29
# Houston Dynamo            29
# Minnesota United          28
# Chicago Fire              28
# Colorado Rapids           28
# Seattle Sounders FC       28
# New York City FC          28
# LAFC                      27
# DC United                 27
# Portland Timbers          27
# New England Revolution    26
# Major League Soccer        8
# Inter Miami                2
# Nashville SC               2
# Name: Club, dtype: int64

# %%
# Identify the teams that are not in MLS in 2019 and drop from the table
outliers = df.loc[(df["Club"] == "Major League Soccer")|(df["Club"] == "Nashville SC")|(df["Club"] == "Inter Miami")].index
outliers
df.drop(outliers, inplace=True)
df
# Out:
#     First Name     Last Name                  Club Position(s)  Base Salary  \
# 0      Brenden      Aaronson    Philadelphia Union         M-F     70000.08
# 1         Saad  Abdul-Salaam   Seattle Sounders FC           D     70250.04
# 2        Lalas      Abubakar       Colorado Rapids           D    135000.00
# 3        David         Accam         Columbus Crew         M-F   1010004.00
# 4       Kellyn        Acosta       Colorado Rapids         D-M    549999.96
# ..         ...           ...                   ...         ...          ...
# 709       Reto       Ziegler             FC Dallas           D    820000.08
# 710     Walker     Zimmerman                  LAFC           D    600000.00
# 711       Kyle        Zobeck             FC Dallas          GK     70875.00
# 712      Ethan         Zubak             LA Galaxy           F     75000.00
# 713     Graham          Zusi  Sporting Kansas City         D-M    625000.08
#
#      Guaranteed Compensation
# 0                   98309.48
# 1                   70250.04
# 2                  144937.50
# 3                 1137920.00
# 4                  664999.96
# ..                       ...
# 709                870000.08
# 710                600000.00
# 711                 70875.00
# 712                 78125.00
# 713                688333.41
#
# [702 rows x 6 columns]

# %%
df.rename(columns={"First Name": "First", "Last Name": "Last", "Position(s)":"Position"}, inplace=True)
df
# Out:
#        First          Last                  Club Position  Base Salary  \
# 0    Brenden      Aaronson    Philadelphia Union      M-F     70000.08
# 1       Saad  Abdul-Salaam   Seattle Sounders FC        D     70250.04
# 2      Lalas      Abubakar       Colorado Rapids        D    135000.00
# 3      David         Accam         Columbus Crew      M-F   1010004.00
# 4     Kellyn        Acosta       Colorado Rapids      D-M    549999.96
# ..       ...           ...                   ...      ...          ...
# 709     Reto       Ziegler             FC Dallas        D    820000.08
# 710   Walker     Zimmerman                  LAFC        D    600000.00
# 711     Kyle        Zobeck             FC Dallas       GK     70875.00
# 712    Ethan         Zubak             LA Galaxy        F     75000.00
# 713   Graham          Zusi  Sporting Kansas City      D-M    625000.08
#
#      Guaranteed Compensation
# 0                   98309.48
# 1                   70250.04
# 2                  144937.50
# 3                 1137920.00
# 4                  664999.96
# ..                       ...
# 709                870000.08
# 710                600000.00
# 711                 70875.00
# 712                 78125.00
# 713                688333.41
#
# [702 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 702 entries, 0 to 713
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   First                    693 non-null    object
#  1   Last                     702 non-null    object
#  2   Club                     702 non-null    object
#  3   Position                 701 non-null    object
#  4   Base Salary              702 non-null    float64
#  5   Guaranteed Compensation  702 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 38.4+ KB

# %%
# find null values to see if missing data will impact intended results
df[df.isnull().any(axis=1)]
# Out:
#        First     Last                  Club Position  Base Salary  \
# 45       NaN    Artur         Columbus Crew      D-M    360000.00
# 51       NaN     Auro            Toronto FC        D    225000.00
# 100      NaN  Bressan             FC Dallas        D    485300.04
# 304      NaN  Ilsinho    Philadelphia Union        M    330000.00
# 324      NaN   Judson  San Jose Earthquakes      D-M    300000.00
# 326      NaN  Juninho             LA Galaxy        M    150000.00
# 328      NaN     Kaku    New York Red Bulls      M-F    799999.92
# 469      NaN     Nani       Orlando City SC      M-F   2333333.04
# 559      NaN  Robinho       Orlando City SC      M-F    198000.00
# 589  Michael  Salazar        Houston Dynamo      NaN     70250.04
#
#      Guaranteed Compensation
# 45                 411633.33
# 51                 276666.67
# 100                521931.29
# 304                357000.00
# 324                305000.00
# 326                163125.00
# 328                799999.92
# 469               2486249.70
# 559                205500.00
# 589                 70250.04

# %%
# reviewed last names to check they are unique players
df.loc[(df["Last"] == "Salazar")]
# Out:
#        First     Last            Club Position  Base Salary  \
# 589  Michael  Salazar  Houston Dynamo      NaN     70250.04
#
#      Guaranteed Compensation
# 589                 70250.04

# %%
df.groupby('Club').head()
roster = df.set_index('Club')
roster
# Out:
#                         First          Last Position  Base Salary  \
# Club
# Philadelphia Union    Brenden      Aaronson      M-F     70000.08
# Seattle Sounders FC      Saad  Abdul-Salaam        D     70250.04
# Colorado Rapids         Lalas      Abubakar        D    135000.00
# Columbus Crew           David         Accam      M-F   1010004.00
# Colorado Rapids        Kellyn        Acosta      D-M    549999.96
# ...                       ...           ...      ...          ...
# FC Dallas                Reto       Ziegler        D    820000.08
# LAFC                   Walker     Zimmerman        D    600000.00
# FC Dallas                Kyle        Zobeck       GK     70875.00
# LA Galaxy               Ethan         Zubak        F     75000.00
# Sporting Kansas City   Graham          Zusi      D-M    625000.08
#
#                       Guaranteed Compensation
# Club
# Philadelphia Union                   98309.48
# Seattle Sounders FC                  70250.04
# Colorado Rapids                     144937.50
# Columbus Crew                      1137920.00
# Colorado Rapids                     664999.96
# ...                                       ...
# FC Dallas                           870000.08
# LAFC                                600000.00
# FC Dallas                            70875.00
# LA Galaxy                            78125.00
# Sporting Kansas City                688333.41
#
# [702 rows x 5 columns]

# %%
final_roster = roster.sort_index()
final_roster
# Out:
#                            First       Last Position  Base Salary  \
# Club
# Atlanta United       Jose Rafael  Hernandez        D    140004.00
# Atlanta United             Mikey    Ambrose        D     72351.60
# Atlanta United              Alec       Kann       GK    100008.00
# Atlanta United              Eric     Remedi      D-M    300000.00
# Atlanta United               Jon  Gallagher      M-F     70250.04
# ...                          ...        ...      ...          ...
# Vancouver Whitecaps  Victor "PC"       Giro      D-M    105000.00
# Vancouver Whitecaps      Anthony   Blondell        F    262500.00
# Vancouver Whitecaps         Jake  Nerwinski        D    120000.00
# Vancouver Whitecaps      Brendan  McDonough        D     56250.00
# Vancouver Whitecaps        Simon      Colyn      M-F     56250.00
#
#                      Guaranteed Compensation
# Club
# Atlanta United                     140004.00
# Atlanta United                      72351.60
# Atlanta United                     100008.00
# Atlanta United                     300000.00
# Atlanta United                      70250.04
# ...                                      ...
# Vancouver Whitecaps                110312.50
# Vancouver Whitecaps                307703.25
# Vancouver Whitecaps                124125.00
# Vancouver Whitecaps                 56250.00
# Vancouver Whitecaps                 81250.00
#
# [702 rows x 5 columns]
